# %% [markdown]
# <a href="https://colab.research.google.com/github/bcarmoai/Colab/blob/main/Boris_course_code_Chapter_4_(BC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
nba = pd.read_csv('https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/refs/heads/master/nba.csv')

# %%
nba.tail(1)
# Out:
#     Name Team  Number Position  Age Height  Weight College  Salary
# 457  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
s = pd.Series([1,2,3,4,5])

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
s.columns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-1a0047058983> in <cell line: 1>()
# ----> 1 s.columns()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
s.axes
# Out:
# [RangeIndex(start=0, stop=5, step=1)]

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
s.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 168.0 bytes

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
revenue = pd.read_csv('https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/refs/heads/master/revenue.csv',index_col='Date')

# %%
revenue.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum(axis="index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum(axis="columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
type(nba.Name)
# Out:
# pandas.core.series.Series

# %%
type(nba["Team"])
# Out:
# pandas.core.series.Series

# %%
nba[["Name","Team"]]
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
nba["Sport"] = 'abc'

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary Sport
# 0              Texas  7730337.0   abc
# 1          Marquette  6796117.0   abc
# 2  Boston University        NaN   abc
# 3      Georgia State  1148640.0   abc
# 4                NaN  5000000.0   abc

# %%
nba = pd.read_csv('https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/refs/heads/master/nba.csv')

# %%
nba.insert(loc=3, column="Sport", value = "Basketball")

# %%
nba.head()
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %%
nba["New Salary"] = nba["Salary"].div(10)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  New Salary
# 0              Texas  7730337.0    773033.7
# 1          Marquette  6796117.0    679611.7
# 2  Boston University        NaN         NaN
# 3      Georgia State  1148640.0    114864.0
# 4                NaN  5000000.0    500000.0

# %%
nba["Team"].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
nba["Position"].value_counts(normalize=True)
# Out:
# Position
# SG    0.223195
# PF    0.218818
# PG    0.201313
# SF    0.185996
# C     0.170678
# Name: proportion, dtype: float64

# %%
nba["Position"].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: count, dtype: int64

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  New Salary
# 0                Texas  7730337.0    773033.7
# 1            Marquette  6796117.0    679611.7
# 2    Boston University        NaN         NaN
# 3        Georgia State  1148640.0    114864.0
# 4                  NaN  5000000.0    500000.0
# ..                 ...        ...         ...
# 453             Butler  2433333.0    243333.3
# 454                NaN   900000.0     90000.0
# 455                NaN  2900000.0    290000.0
# 456             Kansas   947276.0     94727.6
# 457                NaN        NaN         NaN
#
# [458 rows x 10 columns]

# %%
nba.dropna()
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  New Salary
# 0            Texas  7730337.0    773033.7
# 1        Marquette  6796117.0    679611.7
# 3    Georgia State  1148640.0    114864.0
# 6              LSU  1170960.0    117096.0
# 7          Gonzaga  2165160.0    216516.0
# ..             ...        ...         ...
# 449           Duke  1348440.0    134844.0
# 451         Dayton   981348.0     98134.8
# 452       Kentucky  2239800.0    223980.0
# 453         Butler  2433333.0    243333.3
# 456         Kansas   947276.0     94727.6
#
# [364 rows x 10 columns]

# %%
nba.dropna(how="all")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  New Salary
# 0                Texas  7730337.0    773033.7
# 1            Marquette  6796117.0    679611.7
# 2    Boston University        NaN         NaN
# 3        Georgia State  1148640.0    114864.0
# 4                  NaN  5000000.0    500000.0
# ..                 ...        ...         ...
# 452           Kentucky  2239800.0    223980.0
# 453             Butler  2433333.0    243333.3
# 454                NaN   900000.0     90000.0
# 455                NaN  2900000.0    290000.0
# 456             Kansas   947276.0     94727.6
#
# [457 rows x 10 columns]

# %%
nba.dropna(subset=["College"])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  New Salary
# 0                Texas  7730337.0    773033.7
# 1            Marquette  6796117.0    679611.7
# 2    Boston University        NaN         NaN
# 3        Georgia State  1148640.0    114864.0
# 6                  LSU  1170960.0    117096.0
# ..                 ...        ...         ...
# 449               Duke  1348440.0    134844.0
# 451             Dayton   981348.0     98134.8
# 452           Kentucky  2239800.0    223980.0
# 453             Butler  2433333.0    243333.3
# 456             Kansas   947276.0     94727.6
#
# [373 rows x 10 columns]

# %%
nba.dropna(subset=["College", "Salary"])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  New Salary
# 0            Texas  7730337.0    773033.7
# 1        Marquette  6796117.0    679611.7
# 3    Georgia State  1148640.0    114864.0
# 6              LSU  1170960.0    117096.0
# 7          Gonzaga  2165160.0    216516.0
# ..             ...        ...         ...
# 449           Duke  1348440.0    134844.0
# 451         Dayton   981348.0     98134.8
# 452       Kentucky  2239800.0    223980.0
# 453         Butler  2433333.0    243333.3
# 456         Kansas   947276.0     94727.6
#
# [364 rows x 10 columns]

# %%
nba_nona = nba.dropna(how="all")

# %%
nba_nona
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  New Salary
# 0                Texas  7730337.0    773033.7
# 1            Marquette  6796117.0    679611.7
# 2    Boston University        NaN         NaN
# 3        Georgia State  1148640.0    114864.0
# 4                  NaN  5000000.0    500000.0
# ..                 ...        ...         ...
# 452           Kentucky  2239800.0    223980.0
# 453             Butler  2433333.0    243333.3
# 454                NaN   900000.0     90000.0
# 455                NaN  2900000.0    290000.0
# 456             Kansas   947276.0     94727.6
#
# [457 rows x 10 columns]

# %%
nba_nona.fillna(0)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  New Salary
# 0                Texas  7730337.0    773033.7
# 1            Marquette  6796117.0    679611.7
# 2    Boston University        0.0         0.0
# 3        Georgia State  1148640.0    114864.0
# 4                    0  5000000.0    500000.0
# ..                 ...        ...         ...
# 452           Kentucky  2239800.0    223980.0
# 453             Butler  2433333.0    243333.3
# 454                  0   900000.0     90000.0
# 455                  0  2900000.0    290000.0
# 456             Kansas   947276.0     94727.6
#
# [457 rows x 10 columns]

# %%
nba_nona
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  New Salary
# 0                Texas  7730337.0    773033.7
# 1            Marquette  6796117.0    679611.7
# 2    Boston University        NaN         NaN
# 3        Georgia State  1148640.0    114864.0
# 4                  NaN  5000000.0    500000.0
# ..                 ...        ...         ...
# 452           Kentucky  2239800.0    223980.0
# 453             Butler  2433333.0    243333.3
# 454                NaN   900000.0     90000.0
# 455                NaN  2900000.0    290000.0
# 456             Kansas   947276.0     94727.6
#
# [457 rows x 10 columns]

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  New Salary
# 0                Texas  7730337.0    773033.7
# 1            Marquette  6796117.0    679611.7
# 2    Boston University        NaN         NaN
# 3        Georgia State  1148640.0    114864.0
# 4                  NaN  5000000.0    500000.0
# ..                 ...        ...         ...
# 453             Butler  2433333.0    243333.3
# 454                NaN   900000.0     90000.0
# 455                NaN  2900000.0    290000.0
# 456             Kansas   947276.0     94727.6
# 457                NaN        NaN         NaN
#
# [458 rows x 10 columns]

# %%
nba["Salary"] = nba["Salary"].fillna(0)

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  New Salary
# 0                Texas  7730337.0    773033.7
# 1            Marquette  6796117.0    679611.7
# 2    Boston University        0.0         NaN
# 3        Georgia State  1148640.0    114864.0
# 4                  NaN  5000000.0    500000.0
# ..                 ...        ...         ...
# 453             Butler  2433333.0    243333.3
# 454                NaN   900000.0     90000.0
# 455                NaN  2900000.0    290000.0
# 456             Kansas   947276.0     94727.6
# 457                NaN        0.0         NaN
#
# [458 rows x 10 columns]

# %%
nba["College"] = nba["College"].fillna(value="Unknown")

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  New Salary
# 0                Texas  7730337.0    773033.7
# 1            Marquette  6796117.0    679611.7
# 2    Boston University        0.0         NaN
# 3        Georgia State  1148640.0    114864.0
# 4              Unknown  5000000.0    500000.0
# ..                 ...        ...         ...
# 453             Butler  2433333.0    243333.3
# 454            Unknown   900000.0     90000.0
# 455            Unknown  2900000.0    290000.0
# 456             Kansas   947276.0     94727.6
# 457            Unknown        0.0         NaN
#
# [458 rows x 10 columns]

# %%
nba["Salary"].astype("int")
# Out:
# 0      7730337
# 1      6796117
# 2            0
# 3      1148640
# 4      5000000
#         ...
# 453    2433333
# 454     900000
# 455    2900000
# 456     947276
# 457          0
# Name: Salary, Length: 458, dtype: int64

# %%
nba["New Salary"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-24-3e6ebd00630c> in <cell line: 1>()
# ----> 1 nba["New Salary"].astype("int")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow, squeeze)
#     756             values = values[0, :]  # type: ignore[call-overload]
#     757
# --> 758         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     759
#     760         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     235
#     236     try:
# --> 237         new_values = astype_array(values, dtype, copy=copy)
#     238     except (ValueError, TypeError):
#     239         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     180
#     181     else:
# --> 182         values = _astype_nansafe(values, dtype, copy=copy)
#     183
#     184     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#      99
#     100     elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101         return _astype_float_to_int_nansafe(arr, dtype, copy)
#     102
#     103     elif arr.dtype == object:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in _astype_float_to_int_nansafe(values, dtype, copy)
#     143     """
#     144     if not np.isfinite(values).all():
# --> 145         raise IntCastingNaNError(
#     146             "Cannot convert non-finite values (NA or inf) to integer"
#     147         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
nba["New Salary"].fillna(0).astype("int")
# Out:
# 0      773033
# 1      679611
# 2           0
# 3      114864
# 4      500000
#         ...
# 453    243333
# 454     90000
# 455    290000
# 456     94727
# 457         0
# Name: New Salary, Length: 458, dtype: int64

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        457 non-null    object
#  1   Team        457 non-null    object
#  2   Number      457 non-null    float64
#  3   Position    457 non-null    object
#  4   Age         457 non-null    float64
#  5   Height      457 non-null    object
#  6   Weight      457 non-null    float64
#  7   College     458 non-null    object
#  8   Salary      458 non-null    float64
#  9   New Salary  446 non-null    float64
# dtypes: float64(5), object(5)
# memory usage: 35.9+ KB

# %%
nba["Position"] = nba["Position"].astype("category")

# %%
nba["Team"] = nba["Team"].astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        457 non-null    object
#  1   Team        457 non-null    category
#  2   Number      457 non-null    float64
#  3   Position    457 non-null    category
#  4   Age         457 non-null    float64
#  5   Height      457 non-null    object
#  6   Weight      457 non-null    float64
#  7   College     458 non-null    object
#  8   Salary      458 non-null    float64
#  9   New Salary  446 non-null    float64
# dtypes: category(2), float64(5), object(3)
# memory usage: 31.1+ KB

# %%
nba.sort_values(by="Name")
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary  New Salary
# 152   161.0          Oregon   2250000.0    225000.0
# 356   220.0         Arizona   4171680.0    417168.0
# 328   210.0        Kentucky    525093.0     52509.3
# 404   237.0  Michigan State   1938840.0    193884.0
# 312   245.0         Florida  12000000.0   1200000.0
# ..      ...             ...         ...         ...
# 270   180.0    Rhode Island         0.0         NaN
# 402   189.0            UCLA   2148360.0    214836.0
# 271   260.0  Michigan State   9638555.0    963855.5
# 237   275.0         Unknown   5200000.0    520000.0
# 457     NaN         Unknown         0.0         NaN
#
# [458 rows x 10 columns]

# %%
nba.sort_values(by="Name", na_position="first")
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# ..               ...                     ...     ...      ...   ...    ...
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
#
#      Weight         College      Salary  New Salary
# 457     NaN         Unknown         0.0         NaN
# 152   161.0          Oregon   2250000.0    225000.0
# 356   220.0         Arizona   4171680.0    417168.0
# 328   210.0        Kentucky    525093.0     52509.3
# 404   237.0  Michigan State   1938840.0    193884.0
# ..      ...             ...         ...         ...
# 386   225.0          DePaul  10449438.0   1044943.8
# 270   180.0    Rhode Island         0.0         NaN
# 402   189.0            UCLA   2148360.0    214836.0
# 271   260.0  Michigan State   9638555.0    963855.5
# 237   275.0         Unknown   5200000.0    520000.0
#
# [458 rows x 10 columns]

# %%
nba.sort_values(by=["Team","Salary"], ascending=[True, False])
# Out:
#                 Name                Team  Number Position   Age Height  \
# 315     Paul Millsap       Atlanta Hawks     4.0       PF  31.0    6-8
# 312       Al Horford       Atlanta Hawks    15.0        C  30.0   6-10
# 321   Tiago Splitter       Atlanta Hawks    11.0        C  31.0   6-11
# 323      Jeff Teague       Atlanta Hawks     0.0       PG  27.0    6-2
# 314      Kyle Korver       Atlanta Hawks    26.0       SG  35.0    6-7
# ..               ...                 ...     ...      ...   ...    ...
# 380   Garrett Temple  Washington Wizards    17.0       SG  30.0    6-6
# 371     Jarell Eddie  Washington Wizards     8.0       SG  24.0    6-7
# 374       JJ Hickson  Washington Wizards    21.0        C  27.0    6-9
# 381  Marcus Thornton  Washington Wizards    15.0       SF  29.0    6-4
# 457              NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight               College      Salary  New Salary
# 315   246.0        Louisiana Tech  18671659.0   1867165.9
# 312   245.0               Florida  12000000.0   1200000.0
# 321   245.0               Unknown   9756250.0    975625.0
# 323   186.0           Wake Forest   8000000.0    800000.0
# 314   212.0             Creighton   5746479.0    574647.9
# ..      ...                   ...         ...         ...
# 380   195.0                   LSU   1100602.0    110060.2
# 371   218.0         Virginia Tech    561716.0     56171.6
# 374   242.0  North Carolina State    273038.0     27303.8
# 381   205.0                   LSU    200600.0     20060.0
# 457     NaN               Unknown         0.0         NaN
#
# [458 rows x 10 columns]

# %%
# prompt: find what is the index column of the nba dataframe

import pandas as pd
nba = pd.read_csv('https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/refs/heads/master/nba.csv')

# Find the index column
print(nba.index)

# %%
print(nba.index)
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba['Salary'].rank(ascending=False)
# Out:
# 0       97.0
# 1      110.0
# 2      452.5
# 3      322.0
# 4      147.0
#        ...
# 453    241.0
# 454    383.0
# 455    214.5
# 456    367.0
# 457    452.5
# Name: Salary, Length: 458, dtype: float64

# %%
nba['Salary Rank'] = nba['Salary'].rank(ascending=False)

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  New Salary  Salary Rank
# 0                Texas  7730337.0    773033.7         97.0
# 1            Marquette  6796117.0    679611.7        110.0
# 2    Boston University        0.0         NaN        452.5
# 3        Georgia State  1148640.0    114864.0        322.0
# 4              Unknown  5000000.0    500000.0        147.0
# ..                 ...        ...         ...          ...
# 453             Butler  2433333.0    243333.3        241.0
# 454            Unknown   900000.0     90000.0        383.0
# 455            Unknown  2900000.0    290000.0        214.5
# 456             Kansas   947276.0     94727.6        367.0
# 457            Unknown        0.0         NaN        452.5
#
# [458 rows x 11 columns]
