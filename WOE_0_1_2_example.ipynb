# %% [markdown]
# <a href="https://colab.research.google.com/github/bcarmoai/Colab/blob/main/WOE_0_1_2_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Installation of Library
# !pip install woe_iv_bin
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for woe_iv_bin: filename=woe_iv_bin-0.1.2-py3-none-any.whl size=7009 sha256=063d410021a803aaecc8d9ab1381a805064adf54a215b1053d4e24db610da55f
#   Stored in directory: /root/.cache/pip/wheels/d0/43/c7/c3621f812c41cc73b7e48934b86e2aefb462aec3894a3a589f
# Successfully built woe_iv_bin
# ...

# %%
## Load Package
from woe_iv_bin import categorical_woe
from woe_iv_bin import continuous_woe

# %%
import pandas as pd
import numpy as np

# %%
## Data

# Seed for reproducibility
np.random.seed(42)

# Generating synthetic data
n = 1000  # Number of samples
df = pd.DataFrame({
    'target': np.random.binomial(1, p=0.3, size=n),  # Binary target variable with a 30% chance of being 1
    'cat_feature': np.random.choice(['Category 1', 'Category 2', 'Category 3'], size=n),  # Categorical feature
    'cont_feature': np.random.normal(loc=50, scale=15, size=n)  # Continuous feature
})

# Display the first few rows of the dataframe
df.head()
# Out:
#    target cat_feature  cont_feature
# 0       0  Category 3     51.227440
# 1       1  Category 2     48.516655
# 2       1  Category 3     63.786147
# 3       0  Category 3     45.645882
# 4       0  Category 1     54.010885

# %%
# Categorical
woe_results = categorical_woe(df, cat_variable_name='cat_feature', y_df=df['target'])

# %%
woe_results
# Out:
#                  WoE        IV  total_IV
# feature
# Category 1 -0.002976  0.000003  0.000182
# Category 2  0.017221  0.000102  0.000182
# Category 3 -0.015603  0.000077  0.000182

# %%
## Continuous
df_binned, optimized_bins, binning_woe_results = continuous_woe(df, feature = 'cont_feature', target = 'target', max_bins=20, min_samples_bin=0.05)
# Out:
# /usr/local/lib/python3.11/dist-packages/woe_iv_bin/continuous_binning_woe.py:93: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   final_grouped = df.groupby('optimized_binned_feature')[target].agg(['count', 'sum']).rename(columns={'count': 'n_obs', 'sum': 'n_good'})

# %%
binning_woe_results
# Out:
#                                optimized_bin  optimized_WoE  optimized_IV  \
# 0      (4.707317662687622, 32.1791878433128]      -0.024372  3.137819e-05
# 1       (32.1791878433128, 35.9077281428893]       0.002245  2.628047e-07
# 2      (35.9077281428893, 38.80276234387337]      -0.024372  3.137819e-05
# 3    (38.80276234387337, 41.239017125807045]      -0.193106  1.860844e-03
# 4   (41.239017125807045, 43.560877346425876]       0.154529  1.308237e-03
# 5    (43.560877346425876, 45.85229236917647]      -0.680270  2.078071e-02
# 6     (45.85229236917647, 47.43197008702913]       0.094010  4.694620e-04
# 7    (47.43197008702913, 49.472993002336764]       0.239708  3.198346e-03
# 8   (49.472993002336764, 51.043845649058426]      -0.409680  7.943617e-03
# 9    (51.043845649058426, 52.96875698666522]       0.066664  2.392752e-04
# 10    (52.96875698666522, 55.33091196238168]      -0.657318  1.915638e-02
# 11    (55.33091196238168, 59.58665308466522]       0.066664  2.392752e-04
# ...
