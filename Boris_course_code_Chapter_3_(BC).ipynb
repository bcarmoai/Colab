# %% [markdown]
# <a href="https://colab.research.google.com/github/bcarmoai/Colab/blob/main/Boris_course_code_Chapter_3_(BC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ice_cream = ["Chocolate", "Vanilla", "Strawberry", "Rum Raisin"]

# %%
import pandas as pd

# %%
# Copied this to the top for daily re-running
pokemon_idx = pd.read_csv("https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv", index_col=["Name"]).squeeze("columns")

# %%
pokemon = pd.read_csv("https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv", usecols=["Name"]).squeeze("columns")

# %%
# Copied this to the top for daily re-running
google_stock = pd.read_csv("https://raw.githubusercontent.com/Parasgr7/Google-Stock-Price-Prediction/refs/heads/master/Google_Stock_Price_Test.csv", usecols=["Close"]).squeeze("columns")

# %%
pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
menu = {"Filet Mignon": 29.99, "Big Mac": 3.99, "Pizza": 0.99, "Salmon": 29.99}

# %%
menu_series = pd.Series(menu)

# %%
menu_series[0]
# Out:
# <ipython-input-8-337f0d953734>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   menu_series[0]
# 29.99

# %%
menu_series.iloc[0]
# Out:
# 29.99

# %%
menu_series.mean()
# Out:
# 16.24

# %%
two_numerics = {10:1, 20:2}

# %%
two_numerics_series = pd.Series(two_numerics)

# %%
two_numerics_series.mean()
# Out:
# 1.5

# %%
two_numerics_series
# Out:
# 10    1
# 20    2
# dtype: int64

# %%
type(two_numerics)
# Out:
# dict

# %%
type(two_numerics_series.values)
# Out:
# numpy.ndarray

# %%
menu_names = ["Filet Mignon", "Big Mac", "Pizza", "Salmon"]

# %%
menu_prices = [29.99, 3.99, 0.99, 29.99]

# %%
menu_joined = pd.Series(data=menu_prices, index=menu_names)

# %%
menu_joined.mean()
# Out:
# 16.24

# %%
menu_joined_wrong = pd.Series(data=menu_names, index=menu_prices)

# %%
menu_joined_wrong.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-ec4fe7a7d414> in <cell line: 1>()
# ----> 1 menu_joined_wrong.mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6223         **kwargs,
#    6224     ):
# -> 6225         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6226
#    6227     @doc(make_doc("median", ndim=1))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11990         **kwargs,
#   11991     ) -> Series | float:
# > 11992         return self._stat_function(
#   11993             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994         )
#
# ...

# %%
pokemon = pd.read_csv("https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv", usecols=["Name"]).squeeze("columns")

# %%
pokemon
# Out:
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %%
google_stock = pd.read_csv("https://raw.githubusercontent.com/Parasgr7/Google-Stock-Price-Prediction/refs/heads/master/Google_Stock_Price_Test.csv", usecols=["Close"]).squeeze("columns")

# %%
google_stock
# Out:
# 0     786.14
# 1     786.90
# 2     794.02
# 3     806.15
# 4     806.65
# 5     804.79
# 6     807.91
# 7     806.36
# 8     807.88
# 9     804.61
# 10    806.07
# 11    802.17
# 12    805.02
# 13    819.31
# 14    823.87
# 15    835.67
# 16    832.15
# 17    823.31
# 18    802.32
# 19    796.79
# Name: Close, dtype: float64

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
type(google_stock)
# Out:
# pandas.core.series.Series

# %%
pokemon_nosq = pd.read_csv("https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv", usecols=["Name"])

# %%
pokemon_nosq
# Out:
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %%
type(pokemon_nosq)
# Out:
# pandas.core.frame.DataFrame

# %%
pokemon_nosq.head()
# Out:
#                     Name
# 0              Bulbasaur
# 1                Ivysaur
# 2               Venusaur
# 3  VenusaurMega Venusaur
# 4             Charmander

# %%
len(pokemon)
poki_list = list(pokemon)
poki_list
len(list(pokemon))
# Out:
# 1

# %%
poki_list = list(pokemon_nosq)
poki_list
len(list(pokemon))
# Out:
# 1

# %%
google_list = list(google_stock)
google_list
# Out:
# [786.14,
#  786.9,
#  794.02,
#  806.15,
#  806.65,
#  804.79,
#  807.91,
#  806.36,
#  807.88,
#  804.61,
#  806.07,
#  802.17,
#  805.02,
#  819.31,
#  823.87,
#  835.67,
#  832.15,
#  823.31,
#  802.32,
#  796.79]

# %%
poki_head_list = list(pokemon.head(3))
poki_head_list
# Out:
# ['Name']

# %%
# prompt: create a list from the pokemon series

pokemon_list = list(pokemon)
print(pokemon_list)
# Out:
# ['Name']

# %%
pokemon_list = pokemon['Name'].tolist()
print(pokemon_list)
# Out:
# ['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur', 'Charmander', 'Charmeleon', 'Charizard', 'CharizardMega Charizard X', 'CharizardMega Charizard Y', 'Squirtle', 'Wartortle', 'Blastoise', 'BlastoiseMega Blastoise', 'Caterpie', 'Metapod', 'Butterfree', 'Weedle', 'Kakuna', 'Beedrill', 'BeedrillMega Beedrill', 'Pidgey', 'Pidgeotto', 'Pidgeot', 'PidgeotMega Pidgeot', 'Rattata', 'Raticate', 'Spearow', 'Fearow', 'Ekans', 'Arbok', 'Pikachu', 'Raichu', 'Sandshrew', 'Sandslash', 'Nidoran♀', 'Nidorina', 'Nidoqueen', 'Nidoran♂', 'Nidorino', 'Nidoking', 'Clefairy', 'Clefable', 'Vulpix', 'Ninetales', 'Jigglypuff', 'Wigglytuff', 'Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Paras', 'Parasect', 'Venonat', 'Venomoth', 'Diglett', 'Dugtrio', 'Meowth', 'Persian', 'Psyduck', 'Golduck', 'Mankey', 'Primeape', 'Growlithe', 'Arcanine', 'Poliwag', 'Poliwhirl', 'Poliwrath', 'Abra', 'Kadabra', 'Alakazam', 'AlakazamMega Alakazam', 'Machop', 'Machoke', 'Machamp', 'Bellsprout', 'Weepinbell', 'Vic
# ...

# %%
pokemon_list = list(pokemon['Name'])
print(pokemon_list)
# Out:
# ['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur', 'Charmander', 'Charmeleon', 'Charizard', 'CharizardMega Charizard X', 'CharizardMega Charizard Y', 'Squirtle', 'Wartortle', 'Blastoise', 'BlastoiseMega Blastoise', 'Caterpie', 'Metapod', 'Butterfree', 'Weedle', 'Kakuna', 'Beedrill', 'BeedrillMega Beedrill', 'Pidgey', 'Pidgeotto', 'Pidgeot', 'PidgeotMega Pidgeot', 'Rattata', 'Raticate', 'Spearow', 'Fearow', 'Ekans', 'Arbok', 'Pikachu', 'Raichu', 'Sandshrew', 'Sandslash', 'Nidoran♀', 'Nidorina', 'Nidoqueen', 'Nidoran♂', 'Nidorino', 'Nidoking', 'Clefairy', 'Clefable', 'Vulpix', 'Ninetales', 'Jigglypuff', 'Wigglytuff', 'Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Paras', 'Parasect', 'Venonat', 'Venomoth', 'Diglett', 'Dugtrio', 'Meowth', 'Persian', 'Psyduck', 'Golduck', 'Mankey', 'Primeape', 'Growlithe', 'Arcanine', 'Poliwag', 'Poliwhirl', 'Poliwrath', 'Abra', 'Kadabra', 'Alakazam', 'AlakazamMega Alakazam', 'Machop', 'Machoke', 'Machamp', 'Bellsprout', 'Weepinbell', 'Vic
# ...

# %%
"Bulbasaur" in pokemon
# Out:
# False

# %%
"Bulbasaur" in pokemon

# %%
"Bulbasaur" in pokemon_list
# Out:
# True

# %%
0 in pokemon
# Out:
# False

# %%
0 in google_stock
# Out:
# True

# %%
pokemon
# Out:
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %%
0 in pokemon.index
# Out:
# True

# %%
"Bulbasaur" in pokemon.values
# Out:
# True

# %%
pokemon.sort_values(by="Name")
# Out:
#                         Name
# 510                Abomasnow
# 511  AbomasnowMega Abomasnow
# 68                      Abra
# 392                    Absol
# 393          AbsolMega Absol
# ..                       ...
# 632                  Zoroark
# 631                    Zorua
# 46                     Zubat
# 695                 Zweilous
# 794         Zygarde50% Forme
#
# [800 rows x 1 columns]

# %%
pokemon.sort_values(by="Name", ascending=False).tail()
# Out:
#                         Name
# 393          AbsolMega Absol
# 392                    Absol
# 68                      Abra
# 511  AbomasnowMega Abomasnow
# 510                Abomasnow

# %%
pokemon_idx = pd.read_csv("https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv", index_col=["Name"]).squeeze("columns")

# %%
pokemon_idx.head()
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison    318  45      49       49       65
# Ivysaur                2  Grass  Poison    405  60      62       63       80
# Venusaur               3  Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %%
pokemon_idx_nosq = pd.read_csv("https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv", index_col=["Name"])
pokemon_idx_nosq.head()
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison    318  45      49       49       65
# Ivysaur                2  Grass  Poison    405  60      62       63       80
# Venusaur               3  Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %%
type(pokemon_idx)
# Out:
# pandas.core.frame.DataFrame

# %%
type(pokemon_idx_nosq)
# Out:
# pandas.core.frame.DataFrame

# %%
pokemon_idx.iloc[0]
# Out:
# #                  1
# Type 1         Grass
# Type 2        Poison
# Total            318
# HP                45
# Attack            49
# Defense           49
# Sp. Atk           65
# Sp. Def           65
# Speed             45
# Generation         1
# Legendary      False
# Name: Bulbasaur, dtype: object

# %%
pokemon_idx.iloc[[100,200,300]]
# Out:
#              #  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Haunter     93   Ghost  Poison    405  45      50       45      115       55
# Sudowoodo  185    Rock     NaN    410  70     100      115       30       65
# Swellow    277  Normal  Flying    430  60      85       60       50       50
#
#            Speed  Generation  Legendary
# Name
# Haunter       95           1      False
# Sudowoodo     30           2      False
# Swellow      125           3      False

# %%
pokemon_idx.iloc[[0]]
# Out:
#            # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur  1  Grass  Poison    318  45      49       49       65       65
#
#            Speed  Generation  Legendary
# Name
# Bulbasaur     45           1      False

# %%
pokemon_idx.iloc[-8:]
# Out:
#                        #   Type 1  Type 2  Total   HP  Attack  Defense  \
# Name
# Xerneas              716    Fairy     NaN    680  126     131       95
# Yveltal              717     Dark  Flying    680  126     131       95
# Zygarde50% Forme     718   Dragon  Ground    600  108     100      121
# Diancie              719     Rock   Fairy    600   50     100      150
# DiancieMega Diancie  719     Rock   Fairy    700   50     160      110
# HoopaHoopa Confined  720  Psychic   Ghost    600   80     110       60
# HoopaHoopa Unbound   720  Psychic    Dark    680   80     160       60
# Volcanion            721     Fire   Water    600   80     110      120
#
#                      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Xerneas                  131       98     99           6       True
# Yveltal                  131       98     99           6       True
# Zygarde50% Forme          81       95     95           6       True
# ...

# %%
pokemon_idx.loc["Xerneas"]
# Out:
# #               716
# Type 1        Fairy
# Type 2          NaN
# Total           680
# HP              126
# Attack          131
# Defense          95
# Sp. Atk         131
# Sp. Def          98
# Speed            99
# Generation        6
# Legendary      True
# Name: Xerneas, dtype: object

# %%
pokemon_idx.loc["Xeneas"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Xeneas'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-87915341d69e> in <cell line: 1>()
# ----> 1 pokemon_idx.loc["Xeneas"]
#
# ...

# %%
pokemon_idx.get("Xerneas")

# %%
# prompt: provide an example of using pandas get method

# Example using the pokemon_idx Series
value = pokemon_idx.get("Pikachu")
print(value)

# Example with a key that doesn't exist
value = pokemon_idx.get("NonExistentPokemon", default="Not Found")
print(value)
# Out:
# None
# Not Found

# %%
pokemon_idx.get(0)

# %%
# prompt: find pandas version

import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
# Example from https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.get.html

df = pd.DataFrame(
    [
        [24.3, 75.7, "high"],
        [31, 87.8, "high"],
        [22, 71.6, "medium"],
        [35, 95, "medium"],
    ],
    columns=["temp_celsius", "temp_fahrenheit", "windspeed"],
    index=pd.date_range(start="2014-02-12", end="2014-02-15", freq="D"),
)

# %%
df
# Out:
#             temp_celsius  temp_fahrenheit windspeed
# 2014-02-12          24.3             75.7      high
# 2014-02-13          31.0             87.8      high
# 2014-02-14          22.0             71.6    medium
# 2014-02-15          35.0             95.0    medium

# %%
df.get(["temp_celsius", "windspeed"])
# Out:
#             temp_celsius windspeed
# 2014-02-12          24.3      high
# 2014-02-13          31.0      high
# 2014-02-14          22.0    medium
# 2014-02-15          35.0    medium

# %%
df['windspeed'].get('2014-02-12')
# Out:
# 'high'

# %%
pokemon_idx["#"].get("Xerneas")
# Out:
# 716

# %%
pokemon_idx["Type 2"].get("Xerneas")
# Out:
# nan

# %%
pokemon_idx["Type 2"].get("Xerneas") = "Fairy"
# Out:
#   File "<ipython-input-49-abfdb8a66a74>", line 1
#     pokemon_idx["Type 2"].get("Xerneas") = "Fairy"
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
pokemon_idx["Type 2"].loc["Xerneas"]
# Out:
# 'nan'

# %%
pokemon_idx["Type 2"].loc["Xerneas"] = "Fairy"
# Out:
# <ipython-input-64-ee20280629c5>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   pokemon_idx["Type 2"].loc["Xerneas"] = "Fairy"
# <ipython-input-64-ee20280629c5>:1: SettingWithCopyWarning:
# ...

# %%
pokemon_idx.loc["Xerneas", "Type 2"] = "Fairy"

# %%
pokemon_idx.loc["Xerneas", "Type 2"]
# Out:
# 'Fairy'

# %%
pokemon_idx.loc["Xerneas", "Type 2"] = "Fairy2"
pokemon_idx.loc["Xerneas", "Type 2"]
# Out:
# 'Fairy2'

# %%
pokemon_sq = pokemon_idx.squeeze("columns")

# %%
pokemon_sq
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
pokemon_view = pd.read_csv("https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv", usecols=["Name"])

# %%
pokemon_view.head()
# Out:
#                     Name
# 0              Bulbasaur
# 1                Ivysaur
# 2               Venusaur
# 3  VenusaurMega Venusaur
# 4             Charmander

# %%
pokemon_series = pokemon_view.squeeze("columns")

# %%
pokemon_series[0]
# Out:
# 'Bulbasaur'

# %%
pokemon_series[0]='Whatever'

# %%
pokemon_series[0]
# Out:
# 'Whatever'

# %%
pokemon_view.head()
# Out:
#                     Name
# 0               Whatever
# 1                Ivysaur
# 2               Venusaur
# 3  VenusaurMega Venusaur
# 4             Charmander

# %%
type(pokemon_series)
# Out:
# pandas.core.series.Series

# %%
pokemon_series_copy = pokemon_view.squeeze("columns").copy()

# %%
type(pokemon_series_copy)
# Out:
# pandas.core.series.Series

# %%
pokemon_series_copy[0]='Whatever2'

# %%
pokemon_series_copy[0]
# Out:
# 'Whatever2'

# %%
pokemon_view.head()
# Out:
#                     Name
# 0               Whatever
# 1                Ivysaur
# 2               Venusaur
# 3  VenusaurMega Venusaur
# 4             Charmander

# %%
pokemon_series_copy.count()
# Out:
# 800

# %%
pokemon_series_copy.size
# Out:
# 800

# %%
pokemon_series_copy[0]=None

# %%
pokemon_series_copy.count()
# Out:
# 799

# %%
pokemon_series_copy.size
# Out:
# 800

# %%
pokemon_series_copy.describe()
# Out:
# count         799
# unique        799
# top       Ivysaur
# freq            1
# Name: Name, dtype: object

# %%
google_stock.head()
# Out:
# 0    786.14
# 1    786.90
# 2    794.02
# 3    806.15
# 4    806.65
# Name: Close, dtype: float64

# %%
google_stock.add(10).head()
# Out:
# 0    796.14
# 1    796.90
# 2    804.02
# 3    816.15
# 4    816.65
# Name: Close, dtype: float64

# %%
google_stock + 10
# Out:
# 0     796.14
# 1     796.90
# 2     804.02
# 3     816.15
# 4     816.65
# 5     814.79
# 6     817.91
# 7     816.36
# 8     817.88
# 9     814.61
# 10    816.07
# 11    812.17
# 12    815.02
# 13    829.31
# 14    833.87
# 15    845.67
# 16    842.15
# 17    833.31
# 18    812.32
# 19    806.79
# Name: Close, dtype: float64

# %%
pokemon_view.head()
# Out:
#                     Name
# 0               Whatever
# 1                Ivysaur
# 2               Venusaur
# 3  VenusaurMega Venusaur
# 4             Charmander

# %%
pokemon_view.value_counts()
# Out:
# Name
# Abomasnow                1
# PumpkabooAverage Size    1
# Poliwrath                1
# Ponyta                   1
# Poochyena                1
#                         ..
# Goodra                   1
# Goomy                    1
# Gorebyss                 1
# Gothita                  1
# Zygarde50% Forme         1
# Name: count, Length: 800, dtype: int64

# %%
pokemon_view.apply(len)
# Out:
# Name    800
# dtype: int64

# %%
pokemon_series.apply(len)
# Out:
# 0       8
# 1       7
# 2       8
# 3      21
# 4      10
#        ..
# 795     7
# 796    19
# 797    19
# 798    18
# 799     9
# Name: Name, Length: 800, dtype: int64

# %%
def count_of_a(pokemon):
  return pokemon.count('a')

# %%
pokemon_series.apply(count_of_a)
# Out:
# 0      1
# 1      1
# 2      1
# 3      3
# 4      2
#       ..
# 795    1
# 796    3
# 797    2
# 798    2
# 799    1
# Name: Name, Length: 800, dtype: int64

# %%
attack_powers = {"Grass": 10, "Fire": 20, "Water": 30, "Electric": 40}

# %%
type(attack_powers)
# Out:
# dict

# %%
pokemon_2cols = pokemon_idx['Type 1']
pokemon_2cols
# Out:
# Name
# Bulbasaur                  Grass
# Ivysaur                    Grass
# Venusaur                   Grass
# VenusaurMega Venusaur      Grass
# Charmander                  Fire
#                           ...
# Diancie                     Rock
# DiancieMega Diancie         Rock
# HoopaHoopa Confined      Psychic
# HoopaHoopa Unbound       Psychic
# Volcanion                   Fire
# Name: Type 1, Length: 800, dtype: object

# %%
pokemon_2cols.map(attack_powers)
# Out:
# Name
# Bulbasaur                10.0
# Ivysaur                  10.0
# Venusaur                 10.0
# VenusaurMega Venusaur    10.0
# Charmander               20.0
#                          ...
# Diancie                   NaN
# DiancieMega Diancie       NaN
# HoopaHoopa Confined       NaN
# HoopaHoopa Unbound        NaN
# Volcanion                20.0
# Name: Type 1, Length: 800, dtype: float64

# %%
attack_powers_srs = pd.Series({"Grass": 10, "Fire": 20, "Water": 30, "Electric": 40})
attack_powers_srs
# Out:
# Grass       10
# Fire        20
# Water       30
# Electric    40
# dtype: int64

# %%
pokemon_2cols.map(attack_powers)
# Out:
# Name
# Bulbasaur                10.0
# Ivysaur                  10.0
# Venusaur                 10.0
# VenusaurMega Venusaur    10.0
# Charmander               20.0
#                          ...
# Diancie                   NaN
# DiancieMega Diancie       NaN
# HoopaHoopa Confined       NaN
# HoopaHoopa Unbound        NaN
# Volcanion                20.0
# Name: Type 1, Length: 800, dtype: float64
